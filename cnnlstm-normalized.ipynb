# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from models import CNNLSTM
import random

# %% [markdown]
# ## 1. Set Seed to Ensure Reproducibility

# %%
def set_random_seed(seed):
    # Set random seed for CPU
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # Set random seed for GPU if available
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    
    print(f"Random seed set to {seed}")

seed = 2023  # You can replace this with your desired seed value
set_random_seed(seed)
# Out:
# Random seed set to 2023

# %% [markdown]
# ## 2. Data Preparation
# * Training
#     * sEMG subjects: 1-24
#     * sEMG channels: 1, 2, 3, 4
#     * ECG subjects: [16265, 16272, 16273, 16420, 16483, 16539, 16773, 16786, 16795, 17052, 17453, 18177] (9F+3M)
#     * ECG channel: 1
#     * SNR: [0, -1, -2, ..., -14, -15]
# * Validation
#     * sEMG subjects: 25-32
#     * sEMG channels: 5, 6
#     * ECG subjects: [18184, 19088, 19090, 19093, 19140, 19830] (4F+2M)
#     * ECG channel: 1
#     * SNR: [0, -0.5, -1, ..., -14.5, -15]
# * Testing
#     * sEMG subjects: 33-40
#     * sEMG channels: 9, 10
#     * ECG subjects: [18184, 19088, 19090, 19093, 19140, 19830] (4F+2M)
#     * ECG channel: 2
#     * SNR: [0, -0.5, -1, ..., -14.5, -15]

# %%
def mean_variance_normalize(time_series):
    """
    Mean-variance normalize a 1D time series.

    Parameters:
        time_series (numpy.ndarray): The input 1D time series.

    Returns:
        numpy.ndarray: The mean-variance normalized time series.
    """
    # Calculate the mean and standard deviation of the time series.
    mean = np.mean(time_series)
    std_dev = np.std(time_series)
    
    # Ensure there's no division by zero.
    if std_dev == 0:
        raise ValueError("Cannot normalize: Standard deviation is zero.")
    
    # Normalize the time series to have mean 0 and standard deviation 1.
    normalized_series = (time_series - mean) / std_dev
    
    return normalized_series

def normalize_to_unit_energy(signal):
    """
    Normalize a 1D discrete signal to have unit energy.

    Parameters:
        signal (numpy.ndarray): The input 1D discrete signal.

    Returns:
        numpy.ndarray: The signal with unit energy.
    """
    # Calculate the energy of the signal as the sum of the squares of its samples.
    energy = np.sum(np.abs(signal)**2)
    
    # Ensure there's no division by zero.
    if energy == 0:
        raise ValueError("Cannot normalize: Energy is zero.")
    
    # Normalize the signal to have unit energy by dividing by the square root of the energy.
    normalized_signal = signal / np.sqrt(energy)
    
    return normalized_signal

# %%
# Paths to annotation CSV files
train_csv_path = "train_annotations_E1.csv"
val_csv_path = "val_annotations_E1.csv"

# Folder containing .npy files
data_folder = "./mixed_signals_E1"

# Read the CSV files into pandas DataFrames
train_df = pd.read_csv(train_csv_path)
val_df = pd.read_csv(val_csv_path)

# Initialize lists to store data and labels
train_data = []
train_labels = []
val_data = []
val_labels = []

# Read .npy files and their corresponding SNRs
for _, row in train_df.iterrows():
    file_name = row['mixed_name']
    snr = np.array([row['snr']])
    npy_file_path = os.path.join(data_folder, file_name)
    data = np.load(npy_file_path)
    data = mean_variance_normalize(data)
    data = normalize_to_unit_energy(data)
    data = data.reshape(1, 10000)
    train_data.append(data)
    train_labels.append(snr)
    
for _, row in val_df.iterrows():
    file_name = row['mixed_name']
    snr = np.array([row['snr']])
    npy_file_path = os.path.join(data_folder, file_name)
    data = np.load(npy_file_path)
    data = mean_variance_normalize(data)
    data = normalize_to_unit_energy(data)
    data = data.reshape(1, 10000)
    val_data.append(data)
    val_labels.append(snr)

# Convert lists to NumPy arrays
train_data = np.array(train_data)
train_labels = np.array(train_labels)
val_data = np.array(val_data)
val_labels = np.array(val_labels)

# Print the shapes of the loaded data
print("Train data shape:", train_data.shape)
print("Validation data shape:", val_data.shape)
# Out:
# Train data shape: (137792, 1, 10000)
# Validation data shape: (43710, 1, 10000)

# %%
device = 'cuda:2'
train_data = torch.Tensor(train_data).to(device)
train_labels = torch.Tensor(train_labels).to(device)
train_dataset = TensorDataset(train_data, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_data = torch.Tensor(val_data).to(device)
val_labels = torch.Tensor(val_labels).to(device)
val_dataset = TensorDataset(val_data, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# ## 3. Model, Optimizer, and Loss Function

# %%
criterion = nn.MSELoss()

model = CNNLSTM()
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

print(model)
print("Number of trainable parameters: ", sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# CNNLSTM(
#   (conv1): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(16,), stride=(8,))
#     (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(16, 32, kernel_size=(8,), stride=(4,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (lstm): LSTM(32, 256, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Number of trainable parameters:  2241169

# %%
import time

start = time.time()

# %% [markdown]
# ## 4. Training Loop

# %%
num_epochs = 50
steps_per_print = 1000  # Print loss every 1000 steps

# Initialize a list to store the losses
train_losses = []
val_losses = []  # Initialize a list to store validation losses

best_val_loss = float('inf')  # Initialize with a high value
best_epoch = 1

for epoch in range(num_epochs):
    model.train()
    step_counter = 0  # Initialize step counter for the epoch
    epoch_loss = 0.0  # Initialize the epoch loss

    for batch_data, batch_labels in train_dataloader:
        optimizer.zero_grad()
        predictions = model(batch_data)
        loss = criterion(predictions, batch_labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()  # Accumulate the loss for the epoch

        # Increment step counter
        step_counter += 1

        # Print loss every `steps_per_print` steps
        if step_counter % steps_per_print == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step_counter}/{len(train_dataloader)}], Loss: {loss.item():.4f}")

    # Calculate and record the mean loss for the epoch
    mean_epoch_loss = epoch_loss / len(train_dataloader)
    train_losses.append(mean_epoch_loss)

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0

    with torch.no_grad():
        for val_data, val_labels in val_dataloader:
            val_predictions = model(val_data)
            val_loss += criterion(val_predictions, val_labels).item()

    mean_val_loss = val_loss / len(val_dataloader)
    val_losses.append(mean_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}], Mean Epoch Loss: {mean_epoch_loss:.4f}, Mean Validation Loss: {mean_val_loss:.4f}")
    print("==================================================")

    # Check if the current validation loss is the best so far
    if mean_val_loss < best_val_loss:
        best_val_loss = mean_val_loss
        best_epoch = epoch + 1
        # Save the model's state (weights and other parameters)
        torch.save(model.state_dict(), f"./checkpoints/cnnlstm_norm_bestVal.pth")

print(f"Training completed. Best validation loss: {best_val_loss:.4f} at epoch {best_epoch}")
torch.save(model.state_dict(), f'./checkpoints/cnnlstm_norm_{num_epochs}eps.pth')
# Out:
# Epoch [1/50], Step [1000/4306], Loss: 3.8779
# Epoch [1/50], Step [2000/4306], Loss: 0.8721
# Epoch [1/50], Step [3000/4306], Loss: 0.7762
# Epoch [1/50], Step [4000/4306], Loss: 2.5269
# Epoch [1/50], Mean Epoch Loss: 4.2533, Mean Validation Loss: 0.7979
# ==================================================
# Epoch [2/50], Step [1000/4306], Loss: 1.2497
# Epoch [2/50], Step [2000/4306], Loss: 0.6678
# Epoch [2/50], Step [3000/4306], Loss: 0.4174
# Epoch [2/50], Step [4000/4306], Loss: 1.0008
# Epoch [2/50], Mean Epoch Loss: 0.9383, Mean Validation Loss: 2.2929
# ==================================================
# Epoch [3/50], Step [1000/4306], Loss: 0.7523
# Epoch [3/50], Step [2000/4306], Loss: 0.2158
# Epoch [3/50], Step [3000/4306], Loss: 0.5209
# Epoch [3/50], Step [4000/4306], Loss: 1.2778
# Epoch [3/50], Mean Epoch Loss: 0.5056, Mean Validation Loss: 0.8729
# ==================================================
# Epoch [4/50], Step [1000/4306], Loss: 0.1074
# Epoch [4/50], Step [2000/4306], Loss: 0.3457
# Epoch [4/50], Step [3000/4306], Loss: 0.3916
# Epoch [4/50], Step [4000/4306], Loss: 0.2436
# Epoch [4/50], Mean Epoch Loss: 0.3399, Mean Validation Loss: 1.1021
# ==================================================
# Epoch [5/50], Step [1000/4306], Loss: 0.1263
# Epoch [5/50], Step [2000/4306], Loss: 0.1702
# Epoch [5/50], Step [3000/4306], Loss: 0.1251
# Epoch [5/50], Step [4000/4306], Loss: 0.5990
# Epoch [5/50], Mean Epoch Loss: 0.2580, Mean Validation Loss: 0.9818
# ==================================================
# Epoch [6/50], Step [1000/4306], Loss: 0.1784
# Epoch [6/50], Step [2000/4306], Loss: 0.2088
# Epoch [6/50], Step [3000/4306], Loss: 0.2747
# Epoch [6/50], Step [4000/4306], Loss: 0.1817
# Epoch [6/50], Mean Epoch Loss: 0.2048, Mean Validation Loss: 1.2110
# ==================================================
# Epoch [7/50], Step [1000/4306], Loss: 0.4324
# Epoch [7/50], Step [2000/4306], Loss: 0.0457
# Epoch [7/50], Step [3000/4306], Loss: 0.0958
# Epoch [7/50], Step [4000/4306], Loss: 0.1000
# Epoch [7/50], Mean Epoch Loss: 0.1509, Mean Validation Loss: 1.2555
# ==================================================
# Epoch [8/50], Step [1000/4306], Loss: 0.1388
# Epoch [8/50], Step [2000/4306], Loss: 0.0725
# Epoch [8/50], Step [3000/4306], Loss: 0.0763
# Epoch [8/50], Step [4000/4306], Loss: 0.1881
# Epoch [8/50], Mean Epoch Loss: 0.1235, Mean Validation Loss: 1.9515
# ==================================================
# Epoch [9/50], Step [1000/4306], Loss: 0.0623
# Epoch [9/50], Step [2000/4306], Loss: 0.0576
# Epoch [9/50], Step [3000/4306], Loss: 0.1422
# Epoch [9/50], Step [4000/4306], Loss: 0.1191
# Epoch [9/50], Mean Epoch Loss: 0.1066, Mean Validation Loss: 1.1840
# ==================================================
# Epoch [10/50], Step [1000/4306], Loss: 0.1529
# Epoch [10/50], Step [2000/4306], Loss: 0.1318
# Epoch [10/50], Step [3000/4306], Loss: 0.1150
# Epoch [10/50], Step [4000/4306], Loss: 0.1341
# Epoch [10/50], Mean Epoch Loss: 0.0934, Mean Validation Loss: 0.8392
# ==================================================
# Epoch [11/50], Step [1000/4306], Loss: 0.1402
# Epoch [11/50], Step [2000/4306], Loss: 0.1168
# Epoch [11/50], Step [3000/4306], Loss: 0.0519
# Epoch [11/50], Step [4000/4306], Loss: 0.1153
# Epoch [11/50], Mean Epoch Loss: 0.0834, Mean Validation Loss: 1.4933
# ==================================================
# Epoch [12/50], Step [1000/4306], Loss: 0.0595
# Epoch [12/50], Step [2000/4306], Loss: 0.0342
# Epoch [12/50], Step [3000/4306], Loss: 0.1117
# Epoch [12/50], Step [4000/4306], Loss: 0.0543
# Epoch [12/50], Mean Epoch Loss: 0.0737, Mean Validation Loss: 1.5444
# ==================================================
# Epoch [13/50], Step [1000/4306], Loss: 0.1163
# Epoch [13/50], Step [2000/4306], Loss: 0.0518
# Epoch [13/50], Step [3000/4306], Loss: 0.0956
# Epoch [13/50], Step [4000/4306], Loss: 0.0669
# Epoch [13/50], Mean Epoch Loss: 0.0689, Mean Validation Loss: 0.9752
# ==================================================
# Epoch [14/50], Step [1000/4306], Loss: 0.0566
# Epoch [14/50], Step [2000/4306], Loss: 0.0472
# Epoch [14/50], Step [3000/4306], Loss: 0.0711
# Epoch [14/50], Step [4000/4306], Loss: 0.0562
# Epoch [14/50], Mean Epoch Loss: 0.0617, Mean Validation Loss: 1.6662
# ==================================================
# Epoch [15/50], Step [1000/4306], Loss: 0.0337
# Epoch [15/50], Step [2000/4306], Loss: 0.0596
# Epoch [15/50], Step [3000/4306], Loss: 0.0461
# Epoch [15/50], Step [4000/4306], Loss: 0.0431
# Epoch [15/50], Mean Epoch Loss: 0.0588, Mean Validation Loss: 0.7828
# ==================================================
# Epoch [16/50], Step [1000/4306], Loss: 0.0293
# Epoch [16/50], Step [2000/4306], Loss: 0.0433
# Epoch [16/50], Step [3000/4306], Loss: 0.0433
# Epoch [16/50], Step [4000/4306], Loss: 0.0445
# Epoch [16/50], Mean Epoch Loss: 0.0526, Mean Validation Loss: 0.8777
# ==================================================
# Epoch [17/50], Step [1000/4306], Loss: 0.0693
# Epoch [17/50], Step [2000/4306], Loss: 0.0414
# Epoch [17/50], Step [3000/4306], Loss: 0.0508
# Epoch [17/50], Step [4000/4306], Loss: 0.0474
# Epoch [17/50], Mean Epoch Loss: 0.0511, Mean Validation Loss: 0.9781
# ==================================================
# Epoch [18/50], Step [1000/4306], Loss: 0.0696
# Epoch [18/50], Step [2000/4306], Loss: 0.0246
# Epoch [18/50], Step [3000/4306], Loss: 0.0355
# Epoch [18/50], Step [4000/4306], Loss: 0.0807
# Epoch [18/50], Mean Epoch Loss: 0.0475, Mean Validation Loss: 1.0236
# ==================================================
# Epoch [19/50], Step [1000/4306], Loss: 0.0450
# Epoch [19/50], Step [2000/4306], Loss: 0.0326
# Epoch [19/50], Step [3000/4306], Loss: 0.0323
# Epoch [19/50], Step [4000/4306], Loss: 0.0689
# Epoch [19/50], Mean Epoch Loss: 0.0444, Mean Validation Loss: 1.3476
# ==================================================
# Epoch [20/50], Step [1000/4306], Loss: 0.0502
# Epoch [20/50], Step [2000/4306], Loss: 0.0534
# Epoch [20/50], Step [3000/4306], Loss: 0.0190
# Epoch [20/50], Step [4000/4306], Loss: 0.0439
# Epoch [20/50], Mean Epoch Loss: 0.0409, Mean Validation Loss: 0.9774
# ==================================================
# Epoch [21/50], Step [1000/4306], Loss: 0.0320
# Epoch [21/50], Step [2000/4306], Loss: 0.0663
# Epoch [21/50], Step [3000/4306], Loss: 0.0526
# Epoch [21/50], Step [4000/4306], Loss: 0.0263
# Epoch [21/50], Mean Epoch Loss: 0.0401, Mean Validation Loss: 0.7740
# ==================================================
# Epoch [22/50], Step [1000/4306], Loss: 0.0218
# Epoch [22/50], Step [2000/4306], Loss: 0.0266
# Epoch [22/50], Step [3000/4306], Loss: 0.0312
# Epoch [22/50], Step [4000/4306], Loss: 0.0586
# Epoch [22/50], Mean Epoch Loss: 0.0374, Mean Validation Loss: 0.9522
# ==================================================
# Epoch [23/50], Step [1000/4306], Loss: 0.0378
# Epoch [23/50], Step [2000/4306], Loss: 0.0568
# Epoch [23/50], Step [3000/4306], Loss: 0.0307
# Epoch [23/50], Step [4000/4306], Loss: 0.0213
# Epoch [23/50], Mean Epoch Loss: 0.0350, Mean Validation Loss: 1.1673
# ==================================================
# Epoch [24/50], Step [1000/4306], Loss: 0.0290
# Epoch [24/50], Step [2000/4306], Loss: 0.0233
# Epoch [24/50], Step [3000/4306], Loss: 0.0379
# Epoch [24/50], Step [4000/4306], Loss: 0.0320
# Epoch [24/50], Mean Epoch Loss: 0.0338, Mean Validation Loss: 1.6514
# ==================================================
# Epoch [25/50], Step [1000/4306], Loss: 0.0224
# Epoch [25/50], Step [2000/4306], Loss: 0.0398
# Epoch [25/50], Step [3000/4306], Loss: 0.0385
# Epoch [25/50], Step [4000/4306], Loss: 0.0335
# Epoch [25/50], Mean Epoch Loss: 0.0322, Mean Validation Loss: 0.8997
# ==================================================
# Epoch [26/50], Step [1000/4306], Loss: 0.0287
# Epoch [26/50], Step [2000/4306], Loss: 0.0344
# Epoch [26/50], Step [3000/4306], Loss: 0.0754
# Epoch [26/50], Step [4000/4306], Loss: 0.0177
# Epoch [26/50], Mean Epoch Loss: 0.0308, Mean Validation Loss: 1.2582
# ==================================================
# Epoch [27/50], Step [1000/4306], Loss: 0.0383
# Epoch [27/50], Step [2000/4306], Loss: 0.0183
# Epoch [27/50], Step [3000/4306], Loss: 0.0352
# Epoch [27/50], Step [4000/4306], Loss: 0.0190
# Epoch [27/50], Mean Epoch Loss: 0.0308, Mean Validation Loss: 1.2937
# ==================================================
# Epoch [28/50], Step [1000/4306], Loss: 0.0223
# Epoch [28/50], Step [2000/4306], Loss: 0.0262
# Epoch [28/50], Step [3000/4306], Loss: 0.0458
# Epoch [28/50], Step [4000/4306], Loss: 0.0270
# Epoch [28/50], Mean Epoch Loss: 0.0284, Mean Validation Loss: 1.1352
# ==================================================
# Epoch [29/50], Step [1000/4306], Loss: 0.0222
# Epoch [29/50], Step [2000/4306], Loss: 0.0300
# Epoch [29/50], Step [3000/4306], Loss: 0.0273
# Epoch [29/50], Step [4000/4306], Loss: 0.0354
# Epoch [29/50], Mean Epoch Loss: 0.0273, Mean Validation Loss: 0.8064
# ==================================================
# Epoch [30/50], Step [1000/4306], Loss: 0.0704
# Epoch [30/50], Step [2000/4306], Loss: 0.0239
# Epoch [30/50], Step [3000/4306], Loss: 0.0154
# Epoch [30/50], Step [4000/4306], Loss: 0.0318
# Epoch [30/50], Mean Epoch Loss: 0.0268, Mean Validation Loss: 1.1742
# ==================================================
# Epoch [31/50], Step [1000/4306], Loss: 0.0359
# Epoch [31/50], Step [2000/4306], Loss: 0.0264
# Epoch [31/50], Step [3000/4306], Loss: 0.0488
# Epoch [31/50], Step [4000/4306], Loss: 0.0222
# Epoch [31/50], Mean Epoch Loss: 0.0255, Mean Validation Loss: 0.8345
# ==================================================
# Epoch [32/50], Step [1000/4306], Loss: 0.0281
# Epoch [32/50], Step [2000/4306], Loss: 0.0146
# Epoch [32/50], Step [3000/4306], Loss: 0.0171
# Epoch [32/50], Step [4000/4306], Loss: 0.0381
# Epoch [32/50], Mean Epoch Loss: 0.0247, Mean Validation Loss: 1.4686
# ==================================================
# Epoch [33/50], Step [1000/4306], Loss: 0.0449
# Epoch [33/50], Step [2000/4306], Loss: 0.0156
# Epoch [33/50], Step [3000/4306], Loss: 0.0108
# Epoch [33/50], Step [4000/4306], Loss: 0.0457
# Epoch [33/50], Mean Epoch Loss: 0.0231, Mean Validation Loss: 1.0426
# ==================================================
# Epoch [34/50], Step [1000/4306], Loss: 0.0125
# Epoch [34/50], Step [2000/4306], Loss: 0.0198
# Epoch [34/50], Step [3000/4306], Loss: 0.0240
# Epoch [34/50], Step [4000/4306], Loss: 0.0416
# Epoch [34/50], Mean Epoch Loss: 0.0223, Mean Validation Loss: 0.7940
# ==================================================
# Epoch [35/50], Step [1000/4306], Loss: 0.0146
# Epoch [35/50], Step [2000/4306], Loss: 0.0138
# Epoch [35/50], Step [3000/4306], Loss: 0.0220
# Epoch [35/50], Step [4000/4306], Loss: 0.0163
# Epoch [35/50], Mean Epoch Loss: 0.0220, Mean Validation Loss: 1.1539
# ==================================================
# Epoch [36/50], Step [1000/4306], Loss: 0.0227
# Epoch [36/50], Step [2000/4306], Loss: 0.0185
# Epoch [36/50], Step [3000/4306], Loss: 0.0247
# Epoch [36/50], Step [4000/4306], Loss: 0.0164
# Epoch [36/50], Mean Epoch Loss: 0.0216, Mean Validation Loss: 0.9136
# ==================================================
# Epoch [37/50], Step [1000/4306], Loss: 0.0313
# Epoch [37/50], Step [2000/4306], Loss: 0.0068
# Epoch [37/50], Step [3000/4306], Loss: 0.0168
# Epoch [37/50], Step [4000/4306], Loss: 0.0167
# Epoch [37/50], Mean Epoch Loss: 0.0201, Mean Validation Loss: 1.0259
# ==================================================
# Epoch [38/50], Step [1000/4306], Loss: 0.0269
# Epoch [38/50], Step [2000/4306], Loss: 0.0162
# Epoch [38/50], Step [3000/4306], Loss: 0.0229
# Epoch [38/50], Step [4000/4306], Loss: 0.0112
# Epoch [38/50], Mean Epoch Loss: 0.0197, Mean Validation Loss: 1.0325
# ==================================================
# Epoch [39/50], Step [1000/4306], Loss: 0.0200
# Epoch [39/50], Step [2000/4306], Loss: 0.0264
# Epoch [39/50], Step [3000/4306], Loss: 0.0070
# Epoch [39/50], Step [4000/4306], Loss: 0.0250
# Epoch [39/50], Mean Epoch Loss: 0.0189, Mean Validation Loss: 0.9838
# ==================================================
# Epoch [40/50], Step [1000/4306], Loss: 0.0202
# Epoch [40/50], Step [2000/4306], Loss: 0.0168
# Epoch [40/50], Step [3000/4306], Loss: 0.0186
# Epoch [40/50], Step [4000/4306], Loss: 0.0207
# Epoch [40/50], Mean Epoch Loss: 0.0186, Mean Validation Loss: 0.9412
# ==================================================
# Epoch [41/50], Step [1000/4306], Loss: 0.0184
# Epoch [41/50], Step [2000/4306], Loss: 0.0235
# Epoch [41/50], Step [3000/4306], Loss: 0.0221
# Epoch [41/50], Step [4000/4306], Loss: 0.0246
# Epoch [41/50], Mean Epoch Loss: 0.0179, Mean Validation Loss: 1.2999
# ==================================================
# Epoch [42/50], Step [1000/4306], Loss: 0.0158
# Epoch [42/50], Step [2000/4306], Loss: 0.0142
# Epoch [42/50], Step [3000/4306], Loss: 0.0146
# Epoch [42/50], Step [4000/4306], Loss: 0.0109
# Epoch [42/50], Mean Epoch Loss: 0.0176, Mean Validation Loss: 0.8940
# ==================================================
# Epoch [43/50], Step [1000/4306], Loss: 0.0120
# Epoch [43/50], Step [2000/4306], Loss: 0.0128
# Epoch [43/50], Step [3000/4306], Loss: 0.0193
# Epoch [43/50], Step [4000/4306], Loss: 0.0458
# Epoch [43/50], Mean Epoch Loss: 0.0168, Mean Validation Loss: 1.1186
# ==================================================
# Epoch [44/50], Step [1000/4306], Loss: 0.0300
# Epoch [44/50], Step [2000/4306], Loss: 0.0307
# Epoch [44/50], Step [3000/4306], Loss: 0.0118
# Epoch [44/50], Step [4000/4306], Loss: 0.0159
# Epoch [44/50], Mean Epoch Loss: 0.0166, Mean Validation Loss: 0.9786
# ==================================================
# Epoch [45/50], Step [1000/4306], Loss: 0.0132
# Epoch [45/50], Step [2000/4306], Loss: 0.0133
# Epoch [45/50], Step [3000/4306], Loss: 0.0151
# Epoch [45/50], Step [4000/4306], Loss: 0.0132
# Epoch [45/50], Mean Epoch Loss: 0.0158, Mean Validation Loss: 1.1256
# ==================================================
# Epoch [46/50], Step [1000/4306], Loss: 0.0114
# Epoch [46/50], Step [2000/4306], Loss: 0.0163
# Epoch [46/50], Step [3000/4306], Loss: 0.0239
# Epoch [46/50], Step [4000/4306], Loss: 0.0183
# Epoch [46/50], Mean Epoch Loss: 0.0157, Mean Validation Loss: 1.1394
# ==================================================
# Epoch [47/50], Step [1000/4306], Loss: 0.0149
# Epoch [47/50], Step [2000/4306], Loss: 0.0247
# Epoch [47/50], Step [3000/4306], Loss: 0.0114
# Epoch [47/50], Step [4000/4306], Loss: 0.0084
# Epoch [47/50], Mean Epoch Loss: 0.0152, Mean Validation Loss: 1.1287
# ==================================================
# Epoch [48/50], Step [1000/4306], Loss: 0.0112
# Epoch [48/50], Step [2000/4306], Loss: 0.0163
# Epoch [48/50], Step [3000/4306], Loss: 0.0112
# Epoch [48/50], Step [4000/4306], Loss: 0.0103
# Epoch [48/50], Mean Epoch Loss: 0.0143, Mean Validation Loss: 1.0778
# ==================================================
# Epoch [49/50], Step [1000/4306], Loss: 0.0100
# Epoch [49/50], Step [2000/4306], Loss: 0.0075
# Epoch [49/50], Step [3000/4306], Loss: 0.0096
# Epoch [49/50], Step [4000/4306], Loss: 0.0511
# Epoch [49/50], Mean Epoch Loss: 0.0142, Mean Validation Loss: 1.3784
# ==================================================
# Epoch [50/50], Step [1000/4306], Loss: 0.0137
# Epoch [50/50], Step [2000/4306], Loss: 0.0165
# Epoch [50/50], Step [3000/4306], Loss: 0.0143
# Epoch [50/50], Step [4000/4306], Loss: 0.0137
# Epoch [50/50], Mean Epoch Loss: 0.0137, Mean Validation Loss: 1.0915
# ==================================================
# Training completed. Best validation loss: 0.7740 at epoch 21

# %%
end = time.time()
print(end - start)
# Out:
# 17044.840591669083

# %%
# Plot training and validation loss
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss Curve')
plt.legend()  # Show legend indicating the lines
plt.show()

# %%
# Set model to evaluation mode
model.eval()

# Initialize lists to store predictions and labels
train_predictions = []
train_labels = []

train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=False)

# Iterate through training data
with torch.no_grad():
    for batch_data, batch_labels in train_dataloader:
        predictions = model(batch_data)
        train_predictions.append(predictions.cpu())
        train_labels.append(batch_labels.cpu().numpy())

# Concatenate predictions and labels
train_predictions_np = np.concatenate(train_predictions, axis=0)
train_labels_np = np.concatenate(train_labels, axis=0)

# Reshape predictions and labels
train_predictions_flat = train_predictions_np.reshape(-1)
train_labels_flat = train_labels_np.reshape(-1)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(train_labels_flat, train_predictions_flat)

# Calculate correlation coefficients
correlation_matrix = np.corrcoef(train_labels_flat, train_predictions_flat)
correlation_coefficient = correlation_matrix[0, 1]
spearmanr_cc, _ = stats.spearmanr(train_labels_flat, train_predictions_flat)

# Plot predictions against true labels
plt.scatter(train_labels_flat, train_predictions_flat, alpha=0.5, s=10, color='none', edgecolors='black')
plt.xlabel('True SNR')
plt.ylabel('Estimated SNR')
plt.title(f'CC = {correlation_coefficient:.4f}')

# Perform linear regression
m, b = np.polyfit(train_labels_flat, train_predictions_flat, 1)
plt.plot(train_labels_flat, m * train_labels_flat + b, label=f"y = {m:.2f}x + {b:.2f}")
plt.plot(train_labels_flat, train_labels_flat, label="y = x")
plt.legend(loc='upper center')
plt.show()

# Print the results
print(f'Correlation coefficient (CC): {correlation_coefficient:.4f}')
print(f'Spearman rank-order correlation coefficient (SRCC): {spearmanr_cc:.4f}')
print(f'Mean Squared Error (MSE): {mse:.4f}')
# Out:
# Correlation coefficient (CC): 0.9997
# Spearman rank-order correlation coefficient (SRCC): 0.9980
# Mean Squared Error (MSE): 0.0136

# %%
# Calculate the square error for each element
error = (train_labels_flat - train_predictions_flat)**2

# Calculate mean and standard deviation of the error
mean_error = np.mean(error)
std_deviation_error = np.std(error)

# Plot the error distribution as a histogram
plt.hist(error, bins=10, alpha=0.7, color='blue', edgecolor='black', range=(0, 5))
plt.xlabel('Squared Error')
plt.ylabel('Frequency')
plt.title('Error Distribution')
plt.grid(True)
plt.show()

print("Mean Error:", mean_error)
print("Standard Deviation of Error:", std_deviation_error)
# Out:
# Mean Error: 0.013590381
# Standard Deviation of Error: 0.026487121

# %% [markdown]
# ## 5. Validation Loop

# %%
# Set model to evaluation mode
model.eval()

# Initialize lists to store predictions and labels
val_predictions = []
val_labels = []

# Iterate through validation data
with torch.no_grad():
    for batch_data, batch_labels in val_dataloader:
        predictions = model(batch_data)
        val_predictions.append(predictions.cpu())
        val_labels.append(batch_labels.cpu().numpy())

# Concatenate predictions and labels
val_predictions_np = np.concatenate(val_predictions, axis=0)
val_labels_np = np.concatenate(val_labels, axis=0)

# Reshape predictions and labels
val_predictions_flat = val_predictions_np.reshape(-1)
val_labels_flat = val_labels_np.reshape(-1)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(val_labels_flat, val_predictions_flat)

# Calculate correlation coefficients
correlation_matrix = np.corrcoef(val_labels_flat, val_predictions_flat)
correlation_coefficient = correlation_matrix[0, 1]
spearmanr_cc, _ = stats.spearmanr(val_labels_flat, val_predictions_flat)

# Plot predictions against true labels
plt.scatter(val_labels_flat, val_predictions_flat, alpha=0.5, s=10, color='none', edgecolors='black')
plt.xlabel('True SNR')
plt.ylabel('Estimated SNR')
plt.title(f'CC = {correlation_coefficient:.4f}')

# Perform linear regression
m, b = np.polyfit(val_labels_flat, val_predictions_flat, 1)
plt.plot(val_labels_flat, m * val_labels_flat + b, label=f"y = {m:.2f}x + {b:.2f}")
plt.plot(val_labels_flat, val_labels_flat, label="y = x")
plt.legend(loc='upper center')
plt.show()

# Print the results
print(f'Correlation coefficient (CC): {correlation_coefficient:.4f}')
print(f'Spearman rank-order correlation coefficient (SRCC): {spearmanr_cc:.4f}')
print(f'Mean Squared Error (MSE): {mse:.4f}')
# Out:
# Correlation coefficient (CC): 0.9830
# Spearman rank-order correlation coefficient (SRCC): 0.9838
# Mean Squared Error (MSE): 1.0875

# %%
# Calculate the square error for each element
error = (val_labels_flat - val_predictions_flat)**2

# Calculate mean and standard deviation of the error
mean_error = np.mean(error)
std_deviation_error = np.std(error)

# Plot the error distribution as a histogram
plt.hist(error, bins=10, alpha=0.7, color='blue', edgecolor='black', range=(0, 5))
plt.xlabel('Squared Error')
plt.ylabel('Frequency')
plt.title('Error Distribution')
plt.grid(True)
plt.show()

print("Mean Error:", mean_error)
print("Standard Deviation of Error:", std_deviation_error)
# Out:
# Mean Error: 1.0874674
# Standard Deviation of Error: 3.3035638
