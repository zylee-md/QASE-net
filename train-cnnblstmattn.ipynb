# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from models import CNNBLSTMATTN
import random
import time

# %% [markdown]
# ## Set Seed to Ensure Reproducibility

# %%
def set_random_seed(seed):
    # Set random seed for CPU
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # Set random seed for GPU if available
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    
    print(f"Random seed set to {seed}")

seed = 2023  # You can replace this with your desired seed value
set_random_seed(seed)
# Out:
# Random seed set to 2023

# %% [markdown]
# ## Data Preparation
# <!-- * Training
#     * sEMG subjects: 1-24
#     * sEMG channels: 1, 2, 3, 4
#     * ECG subjects: [16265, 16272, 16273, 16420, 16483, 16539, 16773, 16786, 16795, 17052, 17453, 18177] (9F+3M)
#     * ECG channel: 1
#     * SNR: [0, -1, -2, ..., -14, -15]
# * Validation
#     * sEMG subjects: 25-32
#     * sEMG channels: 5, 6
#     * ECG subjects: [18184, 19088, 19090, 19093, 19140, 19830] (4F+2M)
#     * ECG channel: 1
#     * SNR: [0, -0.5, -1, ..., -14.5, -15]
# * Testing
#     * sEMG subjects: 33-40
#     * sEMG channels: 9, 10
#     * ECG subjects: [18184, 19088, 19090, 19093, 19140, 19830] (4F+2M)
#     * ECG channel: 2
#     * SNR: [0, -0.5, -1, ..., -14.5, -15] -->

# %%
# Paths to annotation CSV files
train_csv_path = "train_annotations_E1.csv"
val_csv_path = "val_annotations_E1.csv"

# Folder containing .npy files
data_folder = "./mixed_signals_E1"

# Read the CSV files into pandas DataFrames
train_df = pd.read_csv(train_csv_path)
val_df = pd.read_csv(val_csv_path)

# Initialize lists to store data and labels
train_data = []
train_labels = []
val_data = []
val_labels = []

# Read .npy files and their corresponding SNRs
for _, row in train_df.iterrows():
    file_name = row['mixed_name']
    snr = np.array([row['snr']])
    npy_file_path = os.path.join(data_folder, file_name)
    data = np.load(npy_file_path)
    data = data.reshape(1, 10000)
    train_data.append(data)
    train_labels.append(snr)
    
for _, row in val_df.iterrows():
    file_name = row['mixed_name']
    snr = np.array([row['snr']])
    npy_file_path = os.path.join(data_folder, file_name)
    data = np.load(npy_file_path)
    data = data.reshape(1, 10000)
    val_data.append(data)
    val_labels.append(snr)

# Convert lists to NumPy arrays
train_data = np.array(train_data)
train_labels = np.array(train_labels)
val_data = np.array(val_data)
val_labels = np.array(val_labels)

# Print the shapes of the loaded data
print("Train data shape:", train_data.shape)
print("Validation data shape:", val_data.shape)
# Out:
# Train data shape: (137792, 1, 10000)
# Validation data shape: (43710, 1, 10000)

# %%
device = 'cuda:6'
train_data = torch.Tensor(train_data).to(device)
train_labels = torch.Tensor(train_labels).to(device)
train_dataset = TensorDataset(train_data, train_labels)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_data = torch.Tensor(val_data).to(device)
val_labels = torch.Tensor(val_labels).to(device)
val_dataset = TensorDataset(val_data, val_labels)
val_dataloader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# ## 3. Model, Optimizer, and Loss Function

# %%
criterion = nn.MSELoss()

model = CNNBLSTMATTN()
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

print(model)
print("Number of trainable parameters: ", sum(p.numel() for p in model.parameters() if p.requires_grad))
model_name = model.__class__.__name__
# Out:
# CNNBLSTMATTN2(
#   (conv1): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(16,), stride=(8,))
#     (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(16, 32, kernel_size=(8,), stride=(4,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (lstm): LSTM(32, 64, batch_first=True, bidirectional=True)
#   (attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#   )
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=1, bias=True)
# )
# Number of trainable parameters:  129041

# %% [markdown]
# ## Training

# %%
num_epochs = 30
steps_per_print = 1000  # Print loss every 1000 steps

# Initialize a list to store the losses
train_losses = []
val_losses = []  # Initialize a list to store validation losses

start = time.time()

for epoch in range(num_epochs):
    model.train()
    step_counter = 0  # Initialize step counter for the epoch
    epoch_loss = 0.0  # Initialize the epoch loss

    for batch_data, batch_labels in train_dataloader:
        optimizer.zero_grad()
        predictions = model(batch_data)
        loss = criterion(predictions, batch_labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()  # Accumulate the loss for the epoch

        # Increment step counter
        step_counter += 1

        # Print loss every `steps_per_print` steps
        if step_counter % steps_per_print == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{step_counter}/{len(train_dataloader)}], Loss: {loss.item():.4f}")

    # Calculate and record the mean loss for the epoch
    mean_epoch_loss = epoch_loss / len(train_dataloader)
    train_losses.append(mean_epoch_loss)

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    val_loss = 0.0

    with torch.no_grad():
        for val_data, val_labels in val_dataloader:
            val_predictions = model(val_data)
            val_loss += criterion(val_predictions, val_labels).item()

    mean_val_loss = val_loss / len(val_dataloader)
    val_losses.append(mean_val_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}], Mean Epoch Loss: {mean_epoch_loss:.4f}, Mean Validation Loss: {mean_val_loss:.4f}")
    print("==================================================")
    if epoch+1 == 20:
        torch.save(model.state_dict(), f'./checkpoints/{model_name.lower()}_20eps_seed{seed}.pth')

print(f"Training completed")
torch.save(model.state_dict(), f'./checkpoints/{model_name.lower()}_{num_epochs}eps_seed{seed}.pth')
end = time.time()
# Out:
# Epoch [1/30], Step [1000/4306], Loss: 1.7269
# Epoch [1/30], Step [2000/4306], Loss: 1.2542
# Epoch [1/30], Step [3000/4306], Loss: 1.0184
# Epoch [1/30], Step [4000/4306], Loss: 0.5421
# Epoch [1/30], Mean Epoch Loss: 3.2473, Mean Validation Loss: 0.8233
# ==================================================
# Epoch [2/30], Step [1000/4306], Loss: 0.4753
# Epoch [2/30], Step [2000/4306], Loss: 0.6271
# Epoch [2/30], Step [3000/4306], Loss: 0.3304
# Epoch [2/30], Step [4000/4306], Loss: 0.1801
# Epoch [2/30], Mean Epoch Loss: 0.5328, Mean Validation Loss: 0.5344
# ==================================================
# Epoch [3/30], Step [1000/4306], Loss: 0.2713
# Epoch [3/30], Step [2000/4306], Loss: 0.3389
# Epoch [3/30], Step [3000/4306], Loss: 0.1588
# Epoch [3/30], Step [4000/4306], Loss: 0.2296
# Epoch [3/30], Mean Epoch Loss: 0.2854, Mean Validation Loss: 0.3842
# ==================================================
# Epoch [4/30], Step [1000/4306], Loss: 0.1485
# Epoch [4/30], Step [2000/4306], Loss: 0.1200
# Epoch [4/30], Step [3000/4306], Loss: 0.2018
# Epoch [4/30], Step [4000/4306], Loss: 0.1260
# Epoch [4/30], Mean Epoch Loss: 0.1964, Mean Validation Loss: 0.2992
# ==================================================
# Epoch [5/30], Step [1000/4306], Loss: 0.1097
# Epoch [5/30], Step [2000/4306], Loss: 0.1110
# Epoch [5/30], Step [3000/4306], Loss: 0.1133
# Epoch [5/30], Step [4000/4306], Loss: 0.2167
# Epoch [5/30], Mean Epoch Loss: 0.1574, Mean Validation Loss: 0.2288
# ==================================================
# Epoch [6/30], Step [1000/4306], Loss: 0.1025
# Epoch [6/30], Step [2000/4306], Loss: 0.0825
# Epoch [6/30], Step [3000/4306], Loss: 0.0904
# Epoch [6/30], Step [4000/4306], Loss: 0.1777
# Epoch [6/30], Mean Epoch Loss: 0.1341, Mean Validation Loss: 0.2251
# ==================================================
# Epoch [7/30], Step [1000/4306], Loss: 0.0906
# Epoch [7/30], Step [2000/4306], Loss: 0.1518
# Epoch [7/30], Step [3000/4306], Loss: 0.1746
# Epoch [7/30], Step [4000/4306], Loss: 0.0759
# Epoch [7/30], Mean Epoch Loss: 0.1173, Mean Validation Loss: 0.2929
# ==================================================
# Epoch [8/30], Step [1000/4306], Loss: 0.3206
# Epoch [8/30], Step [2000/4306], Loss: 0.0732
# Epoch [8/30], Step [3000/4306], Loss: 0.0854
# Epoch [8/30], Step [4000/4306], Loss: 0.0501
# Epoch [8/30], Mean Epoch Loss: 0.1094, Mean Validation Loss: 0.2370
# ==================================================
# Epoch [9/30], Step [1000/4306], Loss: 0.0663
# Epoch [9/30], Step [2000/4306], Loss: 0.0622
# Epoch [9/30], Step [3000/4306], Loss: 0.0440
# Epoch [9/30], Step [4000/4306], Loss: 0.0864
# Epoch [9/30], Mean Epoch Loss: 0.1034, Mean Validation Loss: 0.1877
# ==================================================
# Epoch [10/30], Step [1000/4306], Loss: 0.0953
# Epoch [10/30], Step [2000/4306], Loss: 0.0707
# Epoch [10/30], Step [3000/4306], Loss: 0.0694
# Epoch [10/30], Step [4000/4306], Loss: 0.1582
# Epoch [10/30], Mean Epoch Loss: 0.0930, Mean Validation Loss: 0.2006
# ==================================================
# Epoch [11/30], Step [1000/4306], Loss: 0.0661
# Epoch [11/30], Step [2000/4306], Loss: 0.0428
# Epoch [11/30], Step [3000/4306], Loss: 0.0447
# Epoch [11/30], Step [4000/4306], Loss: 0.0758
# Epoch [11/30], Mean Epoch Loss: 0.0878, Mean Validation Loss: 0.2294
# ==================================================
# Epoch [12/30], Step [1000/4306], Loss: 0.1590
# Epoch [12/30], Step [2000/4306], Loss: 0.0718
# Epoch [12/30], Step [3000/4306], Loss: 0.0381
# Epoch [12/30], Step [4000/4306], Loss: 0.0664
# Epoch [12/30], Mean Epoch Loss: 0.0815, Mean Validation Loss: 0.1812
# ==================================================
# Epoch [13/30], Step [1000/4306], Loss: 0.0722
# Epoch [13/30], Step [2000/4306], Loss: 0.0486
# Epoch [13/30], Step [3000/4306], Loss: 0.0554
# Epoch [13/30], Step [4000/4306], Loss: 0.1125
# Epoch [13/30], Mean Epoch Loss: 0.0774, Mean Validation Loss: 0.2076
# ==================================================
# Epoch [14/30], Step [1000/4306], Loss: 0.0397
# Epoch [14/30], Step [2000/4306], Loss: 0.0445
# Epoch [14/30], Step [3000/4306], Loss: 0.0551
# Epoch [14/30], Step [4000/4306], Loss: 0.0610
# Epoch [14/30], Mean Epoch Loss: 0.0742, Mean Validation Loss: 0.2148
# ==================================================
# Epoch [15/30], Step [1000/4306], Loss: 0.0524
# Epoch [15/30], Step [2000/4306], Loss: 0.0590
# Epoch [15/30], Step [3000/4306], Loss: 0.0600
# Epoch [15/30], Step [4000/4306], Loss: 0.2150
# Epoch [15/30], Mean Epoch Loss: 0.0701, Mean Validation Loss: 0.1740
# ==================================================
# Epoch [16/30], Step [1000/4306], Loss: 0.0647
# Epoch [16/30], Step [2000/4306], Loss: 0.0876
# Epoch [16/30], Step [3000/4306], Loss: 0.1695
# Epoch [16/30], Step [4000/4306], Loss: 0.0695
# Epoch [16/30], Mean Epoch Loss: 0.0674, Mean Validation Loss: 0.1802
# ==================================================
# Epoch [17/30], Step [1000/4306], Loss: 0.0920
# Epoch [17/30], Step [2000/4306], Loss: 0.0723
# Epoch [17/30], Step [3000/4306], Loss: 0.0664
# Epoch [17/30], Step [4000/4306], Loss: 0.0590
# Epoch [17/30], Mean Epoch Loss: 0.0641, Mean Validation Loss: 0.1656
# ==================================================
# Epoch [18/30], Step [1000/4306], Loss: 0.0327
# Epoch [18/30], Step [2000/4306], Loss: 0.0935
# Epoch [18/30], Step [3000/4306], Loss: 0.0343
# Epoch [18/30], Step [4000/4306], Loss: 0.0535
# Epoch [18/30], Mean Epoch Loss: 0.0613, Mean Validation Loss: 0.2144
# ==================================================
# Epoch [19/30], Step [1000/4306], Loss: 0.0526
# Epoch [19/30], Step [2000/4306], Loss: 0.0594
# Epoch [19/30], Step [3000/4306], Loss: 0.0448
# Epoch [19/30], Step [4000/4306], Loss: 0.0357
# Epoch [19/30], Mean Epoch Loss: 0.0583, Mean Validation Loss: 0.2371
# ==================================================
# Epoch [20/30], Step [1000/4306], Loss: 0.1116
# Epoch [20/30], Step [2000/4306], Loss: 0.0651
# Epoch [20/30], Step [3000/4306], Loss: 0.0691
# Epoch [20/30], Step [4000/4306], Loss: 0.0507
# Epoch [20/30], Mean Epoch Loss: 0.0573, Mean Validation Loss: 0.2495
# ==================================================
# Epoch [21/30], Step [1000/4306], Loss: 0.1014
# Epoch [21/30], Step [2000/4306], Loss: 0.1214
# Epoch [21/30], Step [3000/4306], Loss: 0.0511
# Epoch [21/30], Step [4000/4306], Loss: 0.0280
# Epoch [21/30], Mean Epoch Loss: 0.0542, Mean Validation Loss: 0.2029
# ==================================================
# Epoch [22/30], Step [1000/4306], Loss: 0.0783
# Epoch [22/30], Step [2000/4306], Loss: 0.0836
# Epoch [22/30], Step [3000/4306], Loss: 0.0400
# Epoch [22/30], Step [4000/4306], Loss: 0.0781
# Epoch [22/30], Mean Epoch Loss: 0.0530, Mean Validation Loss: 0.2069
# ==================================================
# Epoch [23/30], Step [1000/4306], Loss: 0.0628
# Epoch [23/30], Step [2000/4306], Loss: 0.0353
# Epoch [23/30], Step [3000/4306], Loss: 0.0266
# Epoch [23/30], Step [4000/4306], Loss: 0.0285
# Epoch [23/30], Mean Epoch Loss: 0.0508, Mean Validation Loss: 0.1822
# ==================================================
# Epoch [24/30], Step [1000/4306], Loss: 0.0334
# Epoch [24/30], Step [2000/4306], Loss: 0.0351
# Epoch [24/30], Step [3000/4306], Loss: 0.0281
# Epoch [24/30], Step [4000/4306], Loss: 0.0436
# Epoch [24/30], Mean Epoch Loss: 0.0498, Mean Validation Loss: 0.1880
# ==================================================
# Epoch [25/30], Step [1000/4306], Loss: 0.0251
# Epoch [25/30], Step [2000/4306], Loss: 0.0240
# Epoch [25/30], Step [3000/4306], Loss: 0.0238
# Epoch [25/30], Step [4000/4306], Loss: 0.0429
# Epoch [25/30], Mean Epoch Loss: 0.0475, Mean Validation Loss: 0.1863
# ==================================================
# Epoch [26/30], Step [1000/4306], Loss: 0.0409
# Epoch [26/30], Step [2000/4306], Loss: 0.0401
# Epoch [26/30], Step [3000/4306], Loss: 0.0467
# Epoch [26/30], Step [4000/4306], Loss: 0.0736
# Epoch [26/30], Mean Epoch Loss: 0.0466, Mean Validation Loss: 0.1874
# ==================================================
# Epoch [27/30], Step [1000/4306], Loss: 0.0412
# Epoch [27/30], Step [2000/4306], Loss: 0.0268
# Epoch [27/30], Step [3000/4306], Loss: 0.0287
# Epoch [27/30], Step [4000/4306], Loss: 0.0278
# Epoch [27/30], Mean Epoch Loss: 0.0453, Mean Validation Loss: 0.1886
# ==================================================
# Epoch [28/30], Step [1000/4306], Loss: 0.0527
# Epoch [28/30], Step [2000/4306], Loss: 0.0430
# Epoch [28/30], Step [3000/4306], Loss: 0.0544
# Epoch [28/30], Step [4000/4306], Loss: 0.0658
# Epoch [28/30], Mean Epoch Loss: 0.0435, Mean Validation Loss: 0.1909
# ==================================================
# Epoch [29/30], Step [1000/4306], Loss: 0.1279
# Epoch [29/30], Step [2000/4306], Loss: 0.0322
# Epoch [29/30], Step [3000/4306], Loss: 0.0118
# Epoch [29/30], Step [4000/4306], Loss: 0.0352
# Epoch [29/30], Mean Epoch Loss: 0.0424, Mean Validation Loss: 0.1757
# ==================================================
# Epoch [30/30], Step [1000/4306], Loss: 0.0950
# Epoch [30/30], Step [2000/4306], Loss: 0.0436
# Epoch [30/30], Step [3000/4306], Loss: 0.0606
# Epoch [30/30], Step [4000/4306], Loss: 0.0447
# Epoch [30/30], Mean Epoch Loss: 0.0423, Mean Validation Loss: 0.2098
# ==================================================
# Training completed

# %%
# Calculate the training time in seconds
training_time_seconds = end - start
# Convert training time to minutes
training_time_minutes = training_time_seconds // 60

# Print the training time in minutes
print(f"Training time: {training_time_minutes} minutes")
# Out:
# Training time: 49.0 minutes

# %%
# Plot training and validation loss
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Loss Curve')
plt.legend()  # Show legend indicating the lines
plt.show()

# %% [markdown]
# ## Validation

# %%
# Set model to evaluation mode
model.eval()

# Initialize lists to store predictions and labels
val_predictions = []
val_labels = []

# Iterate through validation data
with torch.no_grad():
    for batch_data, batch_labels in val_dataloader:
        predictions = model(batch_data)
        val_predictions.append(predictions.cpu())
        val_labels.append(batch_labels.cpu().numpy())

# %%
# Concatenate predictions and labels
val_predictions_np = np.concatenate(val_predictions, axis=0)
val_labels_np = np.concatenate(val_labels, axis=0)

# Reshape predictions and labels
val_predictions_flat = val_predictions_np.reshape(-1)
val_labels_flat = val_labels_np.reshape(-1)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(val_labels_flat, val_predictions_flat)

# Calculate correlation coefficients
correlation_matrix = np.corrcoef(val_labels_flat, val_predictions_flat)
correlation_coefficient = correlation_matrix[0, 1]
spearmanr_cc, _ = stats.spearmanr(val_labels_flat, val_predictions_flat)

# Plot predictions against true labels
plt.scatter(val_labels_flat, val_predictions_flat, alpha=0.05, s=1, color='black')
plt.xlabel('True SNR')
plt.ylabel('Estimated SNR')
plt.title(f'CC = {correlation_coefficient:.4f}')

# Set x-axis and y-axis limits
plt.xlim(-17.5, 2.5)
plt.ylim(-17.5, 2.5)

# Perform linear regression
m, b = np.polyfit(val_labels_flat, val_predictions_flat, 1)
plt.plot(val_labels_flat, m * val_labels_flat + b, label=f"y = {m:.2f}x + {b:.2f}")
plt.plot(val_labels_flat, val_labels_flat, label="y = x")
plt.legend(loc='upper left')
plt.show()

# Print the results
print(f'Correlation coefficient (CC): {correlation_coefficient:.4f}')
print(f'Spearman rank-order correlation coefficient (SRCC): {spearmanr_cc:.4f}')
print(f'Mean Squared Error (MSE): {mse:.4f}')
# Out:
# Correlation coefficient (CC): 0.9954
# Spearman rank-order correlation coefficient (SRCC): 0.9956
# Mean Squared Error (MSE): 0.2088

# %%
# Calculate the square error for each element
error = (val_labels_flat - val_predictions_flat)**2

# Calculate mean and standard deviation of the error
mean_error = np.mean(error)
std_deviation_error = np.std(error)

# Plot the error distribution as a histogram
hist, bins, _ = plt.hist(error, bins=10, alpha=0.7, color='blue', edgecolor='black', range=(0, 5))
plt.xlabel('Squared Error')
plt.ylabel('Frequency')
plt.title('Squared Error Distribution')
plt.grid(True)

# Annotate each bar with the frequency
for i in range(len(hist)):
    plt.text(bins[i] + (bins[i+1] - bins[i]) / 2, hist[i], f'{int(hist[i])}', ha='center', va='bottom')

plt.show()

print("Mean Error:", mean_error)
print("Standard Deviation of Error:", std_deviation_error)
# Out:
# Mean Error: 0.20882401
# Standard Deviation of Error: 0.46447125

# %%
# Calculate the absolute error for each element
error = np.abs(val_labels_flat - val_predictions_flat)

# Calculate mean and standard deviation of the error
mean_error = np.mean(error)
std_deviation_error = np.std(error)

# Plot the error distribution as a histogram
hist, bins, _ = plt.hist(error, bins=10, alpha=0.7, color='blue', edgecolor='black', range=(0, 5))
plt.xlabel('Absolute Error')
plt.ylabel('Frequency')
plt.title('Squared Error')
plt.grid(True)

# Annotate each bar with the frequency
for i in range(len(hist)):
    plt.text(bins[i] + (bins[i+1] - bins[i]) / 2, hist[i], f'{int(hist[i])}', ha='center', va='bottom')

plt.show()

print("Mean Absolute Error (MAE):", mean_error)
print("Standard Deviation of Absolute Error:", std_deviation_error)
# Out:
# Mean Absolute Error (MAE): 0.3245113
# Standard Deviation of Absolute Error: 0.32173973
